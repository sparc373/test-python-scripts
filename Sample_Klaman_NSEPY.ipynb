# %% [markdown]
# <a href="https://colab.research.google.com/github/sparc373/test-python-scripts/blob/master/Sample_Klaman_NSEPY.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#!pip install nsepy
# Out:
# ...
#   Stored in directory: /root/.cache/pip/wheels/88/89/1e/3dfa14f863314a42481d8926d9ef4825da5d899e026435fc3a
# Successfully built nsepy
# ...

# %%
#!pip install pykalman
from math import pi
import pandas as pd
from bokeh.plotting import figure, show, output_notebook
from nsepy import get_history
from datetime import date
from datetime import datetime
from pykalman import KalmanFilter
import matplotlib
# %matplotlib notebook

# %%
df = get_history(symbol='PNB',start=date(2019,1,2),end = date(2019,2,1))
print(df)
# Out:
#            Symbol Series  Prev Close   Open   High    Low   Last  Close  \
# Date
# 2019-01-02    PNB     EQ       79.80  79.55  80.40  77.30  77.95  77.85
# 2019-01-03    PNB     EQ       77.85  78.10  78.95  77.05  77.80  77.85
# 2019-01-04    PNB     EQ       77.85  78.00  81.90  77.65  81.85  81.30
# 2019-01-07    PNB     EQ       81.30  82.45  82.90  80.00  80.70  80.55
# 2019-01-08    PNB     EQ       80.55  80.55  81.95  79.75  81.75  81.70
# 2019-01-09    PNB     EQ       81.70  82.00  82.15  79.80  80.35  80.70
# 2019-01-10    PNB     EQ       80.70  80.30  81.65  80.10  81.05  81.25
# 2019-01-11    PNB     EQ       81.25  81.25  81.55  80.35  80.45  80.65
# 2019-01-14    PNB     EQ       80.65  80.35  82.90  79.10  82.85  82.50
# 2019-01-15    PNB     EQ       82.50  82.85  83.40  81.50  82.05  81.95
# 2019-01-16    PNB     EQ       81.95  82.00  85.00  81.85  84.05  84.25
# 2019-01-17    PNB     EQ       84.25  84.30  85.05  82.95  84.40  84.55
# ...

# %%
kf = KalmanFilter(transition_matrices = [1],observation_matrices = [1],initial_state_mean = df['Close'].values[0],initial_state_covariance = 1,observation_covariance=1,transition_covariance=.01)

# %%
state_means,_ = kf.filter(df[['Close']].values)
state_means = state_means.flatten()

# %%
df["date"] = pd.to_datetime(df.index)

mids = (df.Open + df.Close)/2
spans = abs(df.Close-df.Open)
inc = df.Close > df.Open
dec = df.Open > df.Close
w = 12*60*60*1000 # half day in ms

output_notebook()

TOOLS = "pan,wheel_zoom,box_zoom,reset,save"
p = figure(x_axis_type="datetime", tools=TOOLS, plot_width=1000, toolbar_location="left",y_axis_label = "Price",x_axis_label = "Date")
p.segment(df.date, df.High, df.date, df.Low, color="black")
p.rect(df.date[inc], mids[inc], w, spans[inc], fill_color='green', line_color="green")
p.rect(df.date[dec], mids[dec], w, spans[dec], fill_color='red', line_color="red")
p.line(df.date,state_means,line_width=1,line_color = 'blue',legend="Kalman filter")
#p.title = "Implementation of Kalman Filter Estimation - TCS EOD chart"
p.xaxis.major_label_orientation = pi/4
p.grid.grid_line_alpha=0.3
show(p)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="2129">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="effe08c2-a304-4451-96b3-1586c77e00f7" data-root-id="2130"></div>
